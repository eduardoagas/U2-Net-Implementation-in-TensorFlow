# %%
import os
os.environ["TF_CPP_MIN_LOG_LEVEL"] = "2"

import tensorflow as tf
from keras.layers import Input, Conv2D, BatchNormalization, Activation, MaxPool2D, UpSampling2D, Concatenate, Add

# %%
def conv_block(inputs, out_ch, rate = 1):
    x = Conv2D(out_ch, 3, padding="same", dilation_rate=1)(inputs)
    x = BatchNormalization()(x)
    x = Activation("relu")(x)
    return x

# %%
def RSU_L(inputs, out_ch, int_ch, num_layers, rate=2):
    """ Initial Convolution """
    x = conv_block(inputs, out_ch)
    init_feats = x
    
    """ Encoder """
    skip = []
    x = conv_block(x, int_ch)
    skip.append(x)
    
    for i in range(num_layers-2):
        x = MaxPool2D((2,2))(x)
        x = conv_block(x, int_ch)
        skip.append(x)

    """ Bridge """
    x = conv_block(x, int_ch, rate=rate)

    """ Decoder """
    skip.reverse()

    x = Concatenate()([x, skip[0]])
    x = conv_block(x, int_ch)

    for i in range(num_layers-3):
        x = UpSampling2D(size=(2,2), interpolation="bilinear")(x)
        x = Concatenate()([x, skip[i+1]])
        x = conv_block(x, int_ch)

    x = UpSampling2D(size=(2,2), interpolation="bilinear")(x)
    x = Concatenate()([x, skip[-1]])
    x = conv_block(x, out_ch)

    """ Add """
    x = Add()([x, init_feats])
    return x

# %%
def RSU_4F(inputs, out_ch, int_ch):
    """ Initial Conv """
    x0 = conv_block(inputs, out_ch, rate=1)

    """ Encoder """
    x1 = conv_block(x0, int_ch, rate=1)
    x2 = conv_block(x1, int_ch, rate=2)
    x3 = conv_block(x2, int_ch, rate=4)

    """ Bridge """
    x4 = conv_block(x3, int_ch, rate=8)

    """ Decoder """
    x = Concatenate()([x4, x3])
    x = conv_block(x, int_ch, rate=4)

    x = Concatenate()([x, x2])
    x = conv_block(x, int_ch, rate=2)

    x = Concatenate()([x, x1])
    x = conv_block(x, out_ch, rate=1)

    """ Addition """
    x = Add()([x, x0])
    return x

# %%
def u2net(input_shape, out_ch, int_ch, num_classes=1):
    """ Input Layer """
    inputs = Input(input_shape)
    s0 = inputs

    """ Encoder """
    s1 = RSU_L(s0, out_ch[0], int_ch[0], 7)
    p1 = MaxPool2D((2,2))(s1)

    s2 = RSU_L(p1, out_ch[1], int_ch[1], 6)
    p2 = MaxPool2D((2,2))(s2)

    s3 = RSU_L(p2, out_ch[2], int_ch[2], 5)
    p3 = MaxPool2D((2,2))(s3)

    s4 = RSU_L(p3, out_ch[3], int_ch[3], 4)
    p4 = MaxPool2D((2,2))(s4)

    s5 = RSU_4F(p4, out_ch[4], int_ch[4])
    p5 = MaxPool2D((2,2))(s5)

    """" Bridge """

    b1 = RSU_4F(p5, out_ch[5], int_ch[5])
    b2 = UpSampling2D(size=(2,2), interpolation="bilinear")(b1)

    """ Decoder """
    d1 = Concatenate()([b2, s5])
    d1 = RSU_4F(d1, out_ch[6], int_ch[6])
    u1 = UpSampling2D(size=(2, 2), interpolation="bilinear")(d1)

    d2 = Concatenate()([u1, s4])
    d2 = RSU_L(d2, out_ch[7], int_ch[7], 4)
    u2 = UpSampling2D(size=(2, 2), interpolation="bilinear")(d2)

    d3 = Concatenate()([u2, s3])
    d3 = RSU_L(d3, out_ch[8], int_ch[8], 5)
    u3 = UpSampling2D(size=(2, 2), interpolation="bilinear")(d3)

    d4 = Concatenate()([u3, s2])
    d4 = RSU_L(d4, out_ch[9], int_ch[9], 6)
    u4 = UpSampling2D(size=(2, 2), interpolation="bilinear")(d4)

    d5 = Concatenate()([u4, s1])
    d5 = RSU_L(d5, out_ch[10], int_ch[10], 7)
    
    """ Side Outputs """
    y1 = Conv2D(num_classes, 3, padding="same")(d5)

    y2 = Conv2D(num_classes, 3, padding="same")(d4)
    y2 = UpSampling2D(size=(2, 2), interpolation="bilinear")(y2)

    y3 = Conv2D(num_classes, 3, padding="same")(d3)
    y3 = UpSampling2D(size=(4, 4), interpolation="bilinear")(y3)

    y4 = Conv2D(num_classes, 3, padding="same")(d2)
    y4 = UpSampling2D(size=(8, 8), interpolation="bilinear")(y4)

    y5 = Conv2D(num_classes, 3, padding="same")(d1)
    y5 = UpSampling2D(size=(16, 16), interpolation="bilinear")(y5)

    y6 = Conv2D(num_classes, 3, padding="same")(b1)
    y6 = UpSampling2D(size=(32, 32), interpolation="bilinear")(y6)

    y0 = Concatenate()([y1, y2, y3, y4, y5, y6])
    y0 = Conv2D(num_classes, 3, padding="same")(y0)

    y0 = Activation("sigmoid")(y0)
    y1 = Activation("sigmoid")(y1)
    y2 = Activation("sigmoid")(y2)
    y3 = Activation("sigmoid")(y3)
    y4 = Activation("sigmoid")(y4)
    y5 = Activation("sigmoid")(y5)
    y6 = Activation("sigmoid")(y6)

    model = tf.keras.models.Model(inputs, outputs=[y0, y1, y2, y3, y4, y5, y6])
    return model

# %%
def build_u2net(input_shape, num_classes=1):
    out_ch = [64, 128, 256, 512, 512, 512, 512, 256, 128, 64, 64]
    int_ch = [32, 32, 64, 128, 256, 256, 256, 128, 64, 32, 16]
    model = u2net(input_shape, out_ch, int_ch, num_classes=num_classes)
    return model

def build_u2net_lite(input_shape, num_classes=1):
    out_ch = [64, 64, 64, 64, 64, 64, 64, 64, 64, 64, 64]
    int_ch = [16, 16, 16, 16, 16, 16, 16, 16, 16, 16, 16]
    model = u2net(input_shape, out_ch, int_ch, num_classes=num_classes)
    return model

# %%
if __name__ == "__main__":
    out_ch = [64, 128, 256, 512, 512, 512, 512, 256, 128, 64, 64]
    int_ch = [32, 32, 64, 128, 256, 256, 256, 128, 64, 32, 16]

    model = build_u2net_lite((512, 512, 3))
    model.summary()
# Out:
# Model: "model_1"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_6 (InputLayer)        [(None, 512, 512, 3)]        0         []
#
#  conv2d_380 (Conv2D)         (None, 512, 512, 64)         1792      ['input_6[0][0]']
#
#  batch_normalization_373 (B  (None, 512, 512, 64)         256       ['conv2d_380[0][0]']
#  atchNormalization)
#
#  activation_380 (Activation  (None, 512, 512, 64)         0         ['batch_normalization_373[0][0
#  )                                                                  ]']
#
#  conv2d_381 (Conv2D)         (None, 512, 512, 16)         9232      ['activation_380[0][0]']
#
#  batch_normalization_374 (B  (None, 512, 512, 16)         64        ['conv2d_381[0][0]']
#  atchNormalization)
#
#  activation_381 (Activation  (None, 512, 512, 16)         0         ['batch_normalization_374[0][0
#  )                                                                  ]']
#
#  max_pooling2d_109 (MaxPool  (None, 256, 256, 16)         0         ['activation_381[0][0]']
#  ing2D)
#
#  conv2d_382 (Conv2D)         (None, 256, 256, 16)         2320      ['max_pooling2d_109[0][0]']
#
#  batch_normalization_375 (B  (None, 256, 256, 16)         64        ['conv2d_382[0][0]']
#  atchNormalization)
#
#  activation_382 (Activation  (None, 256, 256, 16)         0         ['batch_normalization_375[0][0
#  )                                                                  ]']
#
#  max_pooling2d_110 (MaxPool  (None, 128, 128, 16)         0         ['activation_382[0][0]']
#  ing2D)
#
#  conv2d_383 (Conv2D)         (None, 128, 128, 16)         2320      ['max_pooling2d_110[0][0]']
#
#  batch_normalization_376 (B  (None, 128, 128, 16)         64        ['conv2d_383[0][0]']
#  atchNormalization)
#
#  activation_383 (Activation  (None, 128, 128, 16)         0         ['batch_normalization_376[0][0
#  )                                                                  ]']
#
#  max_pooling2d_111 (MaxPool  (None, 64, 64, 16)           0         ['activation_383[0][0]']
#  ing2D)
#
#  conv2d_384 (Conv2D)         (None, 64, 64, 16)           2320      ['max_pooling2d_111[0][0]']
#
#  batch_normalization_377 (B  (None, 64, 64, 16)           64        ['conv2d_384[0][0]']
#  atchNormalization)
#
#  activation_384 (Activation  (None, 64, 64, 16)           0         ['batch_normalization_377[0][0
#  )                                                                  ]']
#
#  max_pooling2d_112 (MaxPool  (None, 32, 32, 16)           0         ['activation_384[0][0]']
#  ing2D)
#
#  conv2d_385 (Conv2D)         (None, 32, 32, 16)           2320      ['max_pooling2d_112[0][0]']
#
#  batch_normalization_378 (B  (None, 32, 32, 16)           64        ['conv2d_385[0][0]']
#  atchNormalization)
#
#  activation_385 (Activation  (None, 32, 32, 16)           0         ['batch_normalization_378[0][0
#  )                                                                  ]']
#
#  max_pooling2d_113 (MaxPool  (None, 16, 16, 16)           0         ['activation_385[0][0]']
#  ing2D)
#
#  conv2d_386 (Conv2D)         (None, 16, 16, 16)           2320      ['max_pooling2d_113[0][0]']
#
#  batch_normalization_379 (B  (None, 16, 16, 16)           64        ['conv2d_386[0][0]']
#  atchNormalization)
#
#  activation_386 (Activation  (None, 16, 16, 16)           0         ['batch_normalization_379[0][0
#  )                                                                  ]']
#
#  conv2d_387 (Conv2D)         (None, 16, 16, 16)           2320      ['activation_386[0][0]']
#
#  batch_normalization_380 (B  (None, 16, 16, 16)           64        ['conv2d_387[0][0]']
#  atchNormalization)
#
#  activation_387 (Activation  (None, 16, 16, 16)           0         ['batch_normalization_380[0][0
#  )                                                                  ]']
#
#  concatenate_163 (Concatena  (None, 16, 16, 32)           0         ['activation_387[0][0]',
#  te)                                                                 'activation_386[0][0]']
#
#  conv2d_388 (Conv2D)         (None, 16, 16, 16)           4624      ['concatenate_163[0][0]']
#
#  batch_normalization_381 (B  (None, 16, 16, 16)           64        ['conv2d_388[0][0]']
#  atchNormalization)
#
#  activation_388 (Activation  (None, 16, 16, 16)           0         ['batch_normalization_381[0][0
#  )                                                                  ]']
#
#  up_sampling2d_108 (UpSampl  (None, 32, 32, 16)           0         ['activation_388[0][0]']
#  ing2D)
#
#  concatenate_164 (Concatena  (None, 32, 32, 32)           0         ['up_sampling2d_108[0][0]',
#  te)                                                                 'activation_385[0][0]']
#
#  conv2d_389 (Conv2D)         (None, 32, 32, 16)           4624      ['concatenate_164[0][0]']
#
#  batch_normalization_382 (B  (None, 32, 32, 16)           64        ['conv2d_389[0][0]']
#  atchNormalization)
#
#  activation_389 (Activation  (None, 32, 32, 16)           0         ['batch_normalization_382[0][0
#  )                                                                  ]']
#
#  up_sampling2d_109 (UpSampl  (None, 64, 64, 16)           0         ['activation_389[0][0]']
#  ing2D)
#
#  concatenate_165 (Concatena  (None, 64, 64, 32)           0         ['up_sampling2d_109[0][0]',
#  te)                                                                 'activation_384[0][0]']
#
#  conv2d_390 (Conv2D)         (None, 64, 64, 16)           4624      ['concatenate_165[0][0]']
#
#  batch_normalization_383 (B  (None, 64, 64, 16)           64        ['conv2d_390[0][0]']
#  atchNormalization)
#
#  activation_390 (Activation  (None, 64, 64, 16)           0         ['batch_normalization_383[0][0
#  )                                                                  ]']
#
#  up_sampling2d_110 (UpSampl  (None, 128, 128, 16)         0         ['activation_390[0][0]']
#  ing2D)
#
#  concatenate_166 (Concatena  (None, 128, 128, 32)         0         ['up_sampling2d_110[0][0]',
#  te)                                                                 'activation_383[0][0]']
#
#  conv2d_391 (Conv2D)         (None, 128, 128, 16)         4624      ['concatenate_166[0][0]']
#
#  batch_normalization_384 (B  (None, 128, 128, 16)         64        ['conv2d_391[0][0]']
#  atchNormalization)
#
#  activation_391 (Activation  (None, 128, 128, 16)         0         ['batch_normalization_384[0][0
#  )                                                                  ]']
#
#  up_sampling2d_111 (UpSampl  (None, 256, 256, 16)         0         ['activation_391[0][0]']
#  ing2D)
#
#  concatenate_167 (Concatena  (None, 256, 256, 32)         0         ['up_sampling2d_111[0][0]',
#  te)                                                                 'activation_382[0][0]']
#
#  conv2d_392 (Conv2D)         (None, 256, 256, 16)         4624      ['concatenate_167[0][0]']
#
#  batch_normalization_385 (B  (None, 256, 256, 16)         64        ['conv2d_392[0][0]']
#  atchNormalization)
#
#  activation_392 (Activation  (None, 256, 256, 16)         0         ['batch_normalization_385[0][0
#  )                                                                  ]']
#
#  up_sampling2d_112 (UpSampl  (None, 512, 512, 16)         0         ['activation_392[0][0]']
#  ing2D)
#
#  concatenate_168 (Concatena  (None, 512, 512, 32)         0         ['up_sampling2d_112[0][0]',
#  te)                                                                 'activation_381[0][0]']
#
#  conv2d_393 (Conv2D)         (None, 512, 512, 64)         18496     ['concatenate_168[0][0]']
#
#  batch_normalization_386 (B  (None, 512, 512, 64)         256       ['conv2d_393[0][0]']
#  atchNormalization)
#
#  activation_393 (Activation  (None, 512, 512, 64)         0         ['batch_normalization_386[0][0
#  )                                                                  ]']
#
#  add_36 (Add)                (None, 512, 512, 64)         0         ['activation_393[0][0]',
#                                                                      'activation_380[0][0]']
#
#  max_pooling2d_114 (MaxPool  (None, 256, 256, 64)         0         ['add_36[0][0]']
#  ing2D)
#
#  conv2d_394 (Conv2D)         (None, 256, 256, 64)         36928     ['max_pooling2d_114[0][0]']
#
#  batch_normalization_387 (B  (None, 256, 256, 64)         256       ['conv2d_394[0][0]']
#  atchNormalization)
#
#  activation_394 (Activation  (None, 256, 256, 64)         0         ['batch_normalization_387[0][0
#  )                                                                  ]']
#
#  conv2d_395 (Conv2D)         (None, 256, 256, 16)         9232      ['activation_394[0][0]']
#
#  batch_normalization_388 (B  (None, 256, 256, 16)         64        ['conv2d_395[0][0]']
#  atchNormalization)
#
#  activation_395 (Activation  (None, 256, 256, 16)         0         ['batch_normalization_388[0][0
#  )                                                                  ]']
#
#  max_pooling2d_115 (MaxPool  (None, 128, 128, 16)         0         ['activation_395[0][0]']
#  ing2D)
#
#  conv2d_396 (Conv2D)         (None, 128, 128, 16)         2320      ['max_pooling2d_115[0][0]']
#
#  batch_normalization_389 (B  (None, 128, 128, 16)         64        ['conv2d_396[0][0]']
#  atchNormalization)
#
#  activation_396 (Activation  (None, 128, 128, 16)         0         ['batch_normalization_389[0][0
#  )                                                                  ]']
#
#  max_pooling2d_116 (MaxPool  (None, 64, 64, 16)           0         ['activation_396[0][0]']
#  ing2D)
#
#  conv2d_397 (Conv2D)         (None, 64, 64, 16)           2320      ['max_pooling2d_116[0][0]']
#
#  batch_normalization_390 (B  (None, 64, 64, 16)           64        ['conv2d_397[0][0]']
#  atchNormalization)
#
#  activation_397 (Activation  (None, 64, 64, 16)           0         ['batch_normalization_390[0][0
#  )                                                                  ]']
#
#  max_pooling2d_117 (MaxPool  (None, 32, 32, 16)           0         ['activation_397[0][0]']
#  ing2D)
#
#  conv2d_398 (Conv2D)         (None, 32, 32, 16)           2320      ['max_pooling2d_117[0][0]']
#
#  batch_normalization_391 (B  (None, 32, 32, 16)           64        ['conv2d_398[0][0]']
#  atchNormalization)
#
#  activation_398 (Activation  (None, 32, 32, 16)           0         ['batch_normalization_391[0][0
#  )                                                                  ]']
#
#  max_pooling2d_118 (MaxPool  (None, 16, 16, 16)           0         ['activation_398[0][0]']
#  ing2D)
#
#  conv2d_399 (Conv2D)         (None, 16, 16, 16)           2320      ['max_pooling2d_118[0][0]']
#
#  batch_normalization_392 (B  (None, 16, 16, 16)           64        ['conv2d_399[0][0]']
#  atchNormalization)
#
#  activation_399 (Activation  (None, 16, 16, 16)           0         ['batch_normalization_392[0][0
#  )                                                                  ]']
#
#  conv2d_400 (Conv2D)         (None, 16, 16, 16)           2320      ['activation_399[0][0]']
#
#  batch_normalization_393 (B  (None, 16, 16, 16)           64        ['conv2d_400[0][0]']
#  atchNormalization)
#
#  activation_400 (Activation  (None, 16, 16, 16)           0         ['batch_normalization_393[0][0
#  )                                                                  ]']
#
#  concatenate_169 (Concatena  (None, 16, 16, 32)           0         ['activation_400[0][0]',
#  te)                                                                 'activation_399[0][0]']
#
#  conv2d_401 (Conv2D)         (None, 16, 16, 16)           4624      ['concatenate_169[0][0]']
#
#  batch_normalization_394 (B  (None, 16, 16, 16)           64        ['conv2d_401[0][0]']
#  atchNormalization)
#
#  activation_401 (Activation  (None, 16, 16, 16)           0         ['batch_normalization_394[0][0
#  )                                                                  ]']
#
#  up_sampling2d_113 (UpSampl  (None, 32, 32, 16)           0         ['activation_401[0][0]']
#  ing2D)
#
#  concatenate_170 (Concatena  (None, 32, 32, 32)           0         ['up_sampling2d_113[0][0]',
#  te)                                                                 'activation_398[0][0]']
#
#  conv2d_402 (Conv2D)         (None, 32, 32, 16)           4624      ['concatenate_170[0][0]']
#
#  batch_normalization_395 (B  (None, 32, 32, 16)           64        ['conv2d_402[0][0]']
#  atchNormalization)
#
#  activation_402 (Activation  (None, 32, 32, 16)           0         ['batch_normalization_395[0][0
#  )                                                                  ]']
#
#  up_sampling2d_114 (UpSampl  (None, 64, 64, 16)           0         ['activation_402[0][0]']
#  ing2D)
#
#  concatenate_171 (Concatena  (None, 64, 64, 32)           0         ['up_sampling2d_114[0][0]',
#  te)                                                                 'activation_397[0][0]']
#
#  conv2d_403 (Conv2D)         (None, 64, 64, 16)           4624      ['concatenate_171[0][0]']
#
#  batch_normalization_396 (B  (None, 64, 64, 16)           64        ['conv2d_403[0][0]']
#  atchNormalization)
#
#  activation_403 (Activation  (None, 64, 64, 16)           0         ['batch_normalization_396[0][0
#  )                                                                  ]']
#
#  up_sampling2d_115 (UpSampl  (None, 128, 128, 16)         0         ['activation_403[0][0]']
#  ing2D)
#
#  concatenate_172 (Concatena  (None, 128, 128, 32)         0         ['up_sampling2d_115[0][0]',
#  te)                                                                 'activation_396[0][0]']
#
#  conv2d_404 (Conv2D)         (None, 128, 128, 16)         4624      ['concatenate_172[0][0]']
#
#  batch_normalization_397 (B  (None, 128, 128, 16)         64        ['conv2d_404[0][0]']
#  atchNormalization)
#
#  activation_404 (Activation  (None, 128, 128, 16)         0         ['batch_normalization_397[0][0
#  )                                                                  ]']
#
#  up_sampling2d_116 (UpSampl  (None, 256, 256, 16)         0         ['activation_404[0][0]']
#  ing2D)
#
#  concatenate_173 (Concatena  (None, 256, 256, 32)         0         ['up_sampling2d_116[0][0]',
#  te)                                                                 'activation_395[0][0]']
#
#  conv2d_405 (Conv2D)         (None, 256, 256, 64)         18496     ['concatenate_173[0][0]']
#
#  batch_normalization_398 (B  (None, 256, 256, 64)         256       ['conv2d_405[0][0]']
#  atchNormalization)
#
#  activation_405 (Activation  (None, 256, 256, 64)         0         ['batch_normalization_398[0][0
#  )                                                                  ]']
#
#  add_37 (Add)                (None, 256, 256, 64)         0         ['activation_405[0][0]',
#                                                                      'activation_394[0][0]']
#
#  max_pooling2d_119 (MaxPool  (None, 128, 128, 64)         0         ['add_37[0][0]']
#  ing2D)
#
#  conv2d_406 (Conv2D)         (None, 128, 128, 64)         36928     ['max_pooling2d_119[0][0]']
#
#  batch_normalization_399 (B  (None, 128, 128, 64)         256       ['conv2d_406[0][0]']
#  atchNormalization)
#
#  activation_406 (Activation  (None, 128, 128, 64)         0         ['batch_normalization_399[0][0
#  )                                                                  ]']
#
#  conv2d_407 (Conv2D)         (None, 128, 128, 16)         9232      ['activation_406[0][0]']
#
#  batch_normalization_400 (B  (None, 128, 128, 16)         64        ['conv2d_407[0][0]']
#  atchNormalization)
#
#  activation_407 (Activation  (None, 128, 128, 16)         0         ['batch_normalization_400[0][0
#  )                                                                  ]']
#
#  max_pooling2d_120 (MaxPool  (None, 64, 64, 16)           0         ['activation_407[0][0]']
#  ing2D)
#
#  conv2d_408 (Conv2D)         (None, 64, 64, 16)           2320      ['max_pooling2d_120[0][0]']
#
#  batch_normalization_401 (B  (None, 64, 64, 16)           64        ['conv2d_408[0][0]']
#  atchNormalization)
#
#  activation_408 (Activation  (None, 64, 64, 16)           0         ['batch_normalization_401[0][0
#  )                                                                  ]']
#
#  max_pooling2d_121 (MaxPool  (None, 32, 32, 16)           0         ['activation_408[0][0]']
#  ing2D)
#
#  conv2d_409 (Conv2D)         (None, 32, 32, 16)           2320      ['max_pooling2d_121[0][0]']
#
#  batch_normalization_402 (B  (None, 32, 32, 16)           64        ['conv2d_409[0][0]']
#  atchNormalization)
#
#  activation_409 (Activation  (None, 32, 32, 16)           0         ['batch_normalization_402[0][0
#  )                                                                  ]']
#
#  max_pooling2d_122 (MaxPool  (None, 16, 16, 16)           0         ['activation_409[0][0]']
#  ing2D)
#
#  conv2d_410 (Conv2D)         (None, 16, 16, 16)           2320      ['max_pooling2d_122[0][0]']
#
#  batch_normalization_403 (B  (None, 16, 16, 16)           64        ['conv2d_410[0][0]']
#  atchNormalization)
#
#  activation_410 (Activation  (None, 16, 16, 16)           0         ['batch_normalization_403[0][0
#  )                                                                  ]']
#
#  conv2d_411 (Conv2D)         (None, 16, 16, 16)           2320      ['activation_410[0][0]']
#
#  batch_normalization_404 (B  (None, 16, 16, 16)           64        ['conv2d_411[0][0]']
#  atchNormalization)
#
#  activation_411 (Activation  (None, 16, 16, 16)           0         ['batch_normalization_404[0][0
#  )                                                                  ]']
#
#  concatenate_174 (Concatena  (None, 16, 16, 32)           0         ['activation_411[0][0]',
#  te)                                                                 'activation_410[0][0]']
#
#  conv2d_412 (Conv2D)         (None, 16, 16, 16)           4624      ['concatenate_174[0][0]']
#
#  batch_normalization_405 (B  (None, 16, 16, 16)           64        ['conv2d_412[0][0]']
#  atchNormalization)
#
#  activation_412 (Activation  (None, 16, 16, 16)           0         ['batch_normalization_405[0][0
#  )                                                                  ]']
#
#  up_sampling2d_117 (UpSampl  (None, 32, 32, 16)           0         ['activation_412[0][0]']
#  ing2D)
#
#  concatenate_175 (Concatena  (None, 32, 32, 32)           0         ['up_sampling2d_117[0][0]',
#  te)                                                                 'activation_409[0][0]']
#
#  conv2d_413 (Conv2D)         (None, 32, 32, 16)           4624      ['concatenate_175[0][0]']
#
#  batch_normalization_406 (B  (None, 32, 32, 16)           64        ['conv2d_413[0][0]']
#  atchNormalization)
#
#  activation_413 (Activation  (None, 32, 32, 16)           0         ['batch_normalization_406[0][0
#  )                                                                  ]']
#
#  up_sampling2d_118 (UpSampl  (None, 64, 64, 16)           0         ['activation_413[0][0]']
#  ing2D)
#
#  concatenate_176 (Concatena  (None, 64, 64, 32)           0         ['up_sampling2d_118[0][0]',
#  te)                                                                 'activation_408[0][0]']
#
#  conv2d_414 (Conv2D)         (None, 64, 64, 16)           4624      ['concatenate_176[0][0]']
#
#  batch_normalization_407 (B  (None, 64, 64, 16)           64        ['conv2d_414[0][0]']
#  atchNormalization)
#
#  activation_414 (Activation  (None, 64, 64, 16)           0         ['batch_normalization_407[0][0
#  )                                                                  ]']
#
#  up_sampling2d_119 (UpSampl  (None, 128, 128, 16)         0         ['activation_414[0][0]']
#  ing2D)
#
#  concatenate_177 (Concatena  (None, 128, 128, 32)         0         ['up_sampling2d_119[0][0]',
#  te)                                                                 'activation_407[0][0]']
#
#  conv2d_415 (Conv2D)         (None, 128, 128, 64)         18496     ['concatenate_177[0][0]']
#
#  batch_normalization_408 (B  (None, 128, 128, 64)         256       ['conv2d_415[0][0]']
#  atchNormalization)
#
#  activation_415 (Activation  (None, 128, 128, 64)         0         ['batch_normalization_408[0][0
#  )                                                                  ]']
#
#  add_38 (Add)                (None, 128, 128, 64)         0         ['activation_415[0][0]',
#                                                                      'activation_406[0][0]']
#
#  max_pooling2d_123 (MaxPool  (None, 64, 64, 64)           0         ['add_38[0][0]']
#  ing2D)
#
#  conv2d_416 (Conv2D)         (None, 64, 64, 64)           36928     ['max_pooling2d_123[0][0]']
#
#  batch_normalization_409 (B  (None, 64, 64, 64)           256       ['conv2d_416[0][0]']
#  atchNormalization)
#
#  activation_416 (Activation  (None, 64, 64, 64)           0         ['batch_normalization_409[0][0
#  )                                                                  ]']
#
#  conv2d_417 (Conv2D)         (None, 64, 64, 16)           9232      ['activation_416[0][0]']
#
#  batch_normalization_410 (B  (None, 64, 64, 16)           64        ['conv2d_417[0][0]']
#  atchNormalization)
#
#  activation_417 (Activation  (None, 64, 64, 16)           0         ['batch_normalization_410[0][0
#  )                                                                  ]']
#
#  max_pooling2d_124 (MaxPool  (None, 32, 32, 16)           0         ['activation_417[0][0]']
#  ing2D)
#
#  conv2d_418 (Conv2D)         (None, 32, 32, 16)           2320      ['max_pooling2d_124[0][0]']
#
#  batch_normalization_411 (B  (None, 32, 32, 16)           64        ['conv2d_418[0][0]']
#  atchNormalization)
#
#  activation_418 (Activation  (None, 32, 32, 16)           0         ['batch_normalization_411[0][0
#  )                                                                  ]']
#
#  max_pooling2d_125 (MaxPool  (None, 16, 16, 16)           0         ['activation_418[0][0]']
#  ing2D)
#
#  conv2d_419 (Conv2D)         (None, 16, 16, 16)           2320      ['max_pooling2d_125[0][0]']
#
#  batch_normalization_412 (B  (None, 16, 16, 16)           64        ['conv2d_419[0][0]']
#  atchNormalization)
#
#  activation_419 (Activation  (None, 16, 16, 16)           0         ['batch_normalization_412[0][0
#  )                                                                  ]']
#
#  conv2d_420 (Conv2D)         (None, 16, 16, 16)           2320      ['activation_419[0][0]']
#
#  batch_normalization_413 (B  (None, 16, 16, 16)           64        ['conv2d_420[0][0]']
#  atchNormalization)
#
#  activation_420 (Activation  (None, 16, 16, 16)           0         ['batch_normalization_413[0][0
#  )                                                                  ]']
#
#  concatenate_178 (Concatena  (None, 16, 16, 32)           0         ['activation_420[0][0]',
#  te)                                                                 'activation_419[0][0]']
#
#  conv2d_421 (Conv2D)         (None, 16, 16, 16)           4624      ['concatenate_178[0][0]']
#
#  batch_normalization_414 (B  (None, 16, 16, 16)           64        ['conv2d_421[0][0]']
#  atchNormalization)
#
#  activation_421 (Activation  (None, 16, 16, 16)           0         ['batch_normalization_414[0][0
#  )                                                                  ]']
# ...
#
#  conv2d_484 (Conv2D)         (None, 16, 16, 16)           2320      ['max_pooling2d_141[0][0]']
#
#  batch_normalization_477 (B  (None, 16, 16, 16)           64        ['conv2d_484[0][0]']
#  atchNormalization)
#
#  activation_484 (Activation  (None, 16, 16, 16)           0         ['batch_normalization_477[0][0
#  )                                                                  ]']
#
#  conv2d_485 (Conv2D)         (None, 16, 16, 16)           2320      ['activation_484[0][0]']
#
#  batch_normalization_478 (B  (None, 16, 16, 16)           64        ['conv2d_485[0][0]']
#  atchNormalization)
#
#  activation_485 (Activation  (None, 16, 16, 16)           0         ['batch_normalization_478[0][0
#  )                                                                  ]']
#
#  concatenate_207 (Concatena  (None, 16, 16, 32)           0         ['activation_485[0][0]',
#  te)                                                                 'activation_484[0][0]']
#
#  conv2d_486 (Conv2D)         (None, 16, 16, 16)           4624      ['concatenate_207[0][0]']
#
#  batch_normalization_479 (B  (None, 16, 16, 16)           64        ['conv2d_486[0][0]']
#  atchNormalization)
#
#  activation_486 (Activation  (None, 16, 16, 16)           0         ['batch_normalization_479[0][0
#  )                                                                  ]']
#
#  up_sampling2d_136 (UpSampl  (None, 32, 32, 16)           0         ['activation_486[0][0]']
#  ing2D)
#
#  concatenate_208 (Concatena  (None, 32, 32, 32)           0         ['up_sampling2d_136[0][0]',
#  te)                                                                 'activation_483[0][0]']
#
#  conv2d_487 (Conv2D)         (None, 32, 32, 16)           4624      ['concatenate_208[0][0]']
#
#  batch_normalization_480 (B  (None, 32, 32, 16)           64        ['conv2d_487[0][0]']
#  atchNormalization)
#
#  activation_487 (Activation  (None, 32, 32, 16)           0         ['batch_normalization_480[0][0
#  )                                                                  ]']
#
#  up_sampling2d_137 (UpSampl  (None, 64, 64, 16)           0         ['activation_487[0][0]']
#  ing2D)
#
#  concatenate_209 (Concatena  (None, 64, 64, 32)           0         ['up_sampling2d_137[0][0]',
#  te)                                                                 'activation_482[0][0]']
#
#  conv2d_488 (Conv2D)         (None, 64, 64, 16)           4624      ['concatenate_209[0][0]']
#
#  batch_normalization_481 (B  (None, 64, 64, 16)           64        ['conv2d_488[0][0]']
#  atchNormalization)
#
#  activation_488 (Activation  (None, 64, 64, 16)           0         ['batch_normalization_481[0][0
#  )                                                                  ]']
#
#  up_sampling2d_138 (UpSampl  (None, 128, 128, 16)         0         ['activation_488[0][0]']
#  ing2D)
#
#  concatenate_210 (Concatena  (None, 128, 128, 32)         0         ['up_sampling2d_138[0][0]',
#  te)                                                                 'activation_481[0][0]']
#
#  conv2d_489 (Conv2D)         (None, 128, 128, 16)         4624      ['concatenate_210[0][0]']
#
#  batch_normalization_482 (B  (None, 128, 128, 16)         64        ['conv2d_489[0][0]']
#  atchNormalization)
#
#  activation_489 (Activation  (None, 128, 128, 16)         0         ['batch_normalization_482[0][0
#  )                                                                  ]']
#
#  up_sampling2d_139 (UpSampl  (None, 256, 256, 16)         0         ['activation_489[0][0]']
#  ing2D)
#
#  concatenate_211 (Concatena  (None, 256, 256, 32)         0         ['up_sampling2d_139[0][0]',
#  te)                                                                 'activation_480[0][0]']
#
#  conv2d_490 (Conv2D)         (None, 256, 256, 16)         4624      ['concatenate_211[0][0]']
#
#  batch_normalization_483 (B  (None, 256, 256, 16)         64        ['conv2d_490[0][0]']
#  atchNormalization)
#
#  activation_490 (Activation  (None, 256, 256, 16)         0         ['batch_normalization_483[0][0
#  )                                                                  ]']
#
#  up_sampling2d_140 (UpSampl  (None, 512, 512, 16)         0         ['activation_490[0][0]']
#  ing2D)
#
#  concatenate_212 (Concatena  (None, 512, 512, 32)         0         ['up_sampling2d_140[0][0]',
#  te)                                                                 'activation_479[0][0]']
#
#  conv2d_491 (Conv2D)         (None, 512, 512, 64)         18496     ['concatenate_212[0][0]']
#
#  batch_normalization_484 (B  (None, 512, 512, 64)         256       ['conv2d_491[0][0]']
#  atchNormalization)
#
#  activation_491 (Activation  (None, 512, 512, 64)         0         ['batch_normalization_484[0][0
#  )                                                                  ]']
#
#  add_46 (Add)                (None, 512, 512, 64)         0         ['activation_491[0][0]',
#                                                                      'activation_478[0][0]']
#
#  conv2d_493 (Conv2D)         (None, 256, 256, 1)          577       ['add_45[0][0]']
#
#  conv2d_494 (Conv2D)         (None, 128, 128, 1)          577       ['add_44[0][0]']
#
#  conv2d_495 (Conv2D)         (None, 64, 64, 1)            577       ['add_43[0][0]']
#
#  conv2d_496 (Conv2D)         (None, 32, 32, 1)            577       ['add_42[0][0]']
#
#  conv2d_497 (Conv2D)         (None, 16, 16, 1)            577       ['add_41[0][0]']
#
#  conv2d_492 (Conv2D)         (None, 512, 512, 1)          577       ['add_46[0][0]']
#
#  up_sampling2d_141 (UpSampl  (None, 512, 512, 1)          0         ['conv2d_493[0][0]']
#  ing2D)
#
#  up_sampling2d_142 (UpSampl  (None, 512, 512, 1)          0         ['conv2d_494[0][0]']
#  ing2D)
#
#  up_sampling2d_143 (UpSampl  (None, 512, 512, 1)          0         ['conv2d_495[0][0]']
#  ing2D)
#
#  up_sampling2d_144 (UpSampl  (None, 512, 512, 1)          0         ['conv2d_496[0][0]']
#  ing2D)
#
#  up_sampling2d_145 (UpSampl  (None, 512, 512, 1)          0         ['conv2d_497[0][0]']
#  ing2D)
#
#  concatenate_213 (Concatena  (None, 512, 512, 6)          0         ['conv2d_492[0][0]',
#  te)                                                                 'up_sampling2d_141[0][0]',
#                                                                      'up_sampling2d_142[0][0]',
#                                                                      'up_sampling2d_143[0][0]',
#                                                                      'up_sampling2d_144[0][0]',
#                                                                      'up_sampling2d_145[0][0]']
#
#  conv2d_498 (Conv2D)         (None, 512, 512, 1)          55        ['concatenate_213[0][0]']
#
#  activation_492 (Activation  (None, 512, 512, 1)          0         ['conv2d_498[0][0]']
#  )
#
#  activation_493 (Activation  (None, 512, 512, 1)          0         ['conv2d_492[0][0]']
#  )
#
#  activation_494 (Activation  (None, 512, 512, 1)          0         ['up_sampling2d_141[0][0]']
#  )
#
#  activation_495 (Activation  (None, 512, 512, 1)          0         ['up_sampling2d_142[0][0]']
#  )
#
#  activation_496 (Activation  (None, 512, 512, 1)          0         ['up_sampling2d_143[0][0]']
#  )
#
#  activation_497 (Activation  (None, 512, 512, 1)          0         ['up_sampling2d_144[0][0]']
#  )
#
#  activation_498 (Activation  (None, 512, 512, 1)          0         ['up_sampling2d_145[0][0]']
#  )
#
# ==================================================================================================
# Total params: 1136925 (4.34 MB)
# Trainable params: 1131229 (4.32 MB)
# Non-trainable params: 5696 (22.25 KB)
# __________________________________________________________________________________________________
